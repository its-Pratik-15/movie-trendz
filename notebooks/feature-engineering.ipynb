# %%
import numpy as np 
import pandas as pd

# %%
df =  pd.read_csv('/kaggle/input/processed-movie-data/processed.csv') 
df
# Out:
#                                                 name          rating  \
# 0                                        The Shining               R
# 1                                    The Blue Lagoon               R
# 2     Star Wars: Episode V - The Empire Strikes Back              PG
# 3                                          Airplane!              PG
# 4                                         Caddyshack               R
# ...                                              ...             ...
# 7657                                Aloha Surf Hotel  Unknown Rating
# 7658                                    More to Life  Unknown Rating
# 7659                                     Dream Round  Unknown Rating
# 7660                                   Saving Mbango  Unknown Rating
# 7661                                       Tee em el  Unknown Rating
#
#           genre  year                          released  score      votes  \
# 0         Drama  1980     June 13, 1980 (United States)    8.4   927000.0
# 1     Adventure  1980      July 2, 1980 (United States)    5.8    65000.0
# 2        Action  1980     June 20, 1980 (United States)    8.7  1200000.0
# 3        Comedy  1980      July 2, 1980 (United States)    7.7   221000.0
# 4        Comedy  1980     July 25, 1980 (United States)    7.3   108000.0
# ...         ...   ...                               ...    ...        ...
# 7657     Comedy  2020  November 5, 2020 (United States)    7.1       14.0
# 7658      Drama  2020  October 23, 2020 (United States)    3.1       18.0
# 7659     Comedy  2020  February 7, 2020 (United States)    4.7       36.0
# 7660      Drama  2020         April 27, 2020 (Cameroon)    5.7       29.0
# 7661     Horror  2020   August 19, 2020 (United States)    5.7        7.0
#
#                 director                   writer              star  \
# 0        Stanley Kubrick             Stephen King    Jack Nicholson
# 1         Randal Kleiser  Henry De Vere Stacpoole    Brooke Shields
# 2         Irvin Kershner           Leigh Brackett       Mark Hamill
# 3           Jim Abrahams             Jim Abrahams       Robert Hays
# 4           Harold Ramis       Brian Doyle-Murray       Chevy Chase
# ...                  ...                      ...               ...
# 7657  Stefan C. Schaefer       Stefan C. Schaefer       Augie Tulba
# 7658       Joseph Ebanks            Joseph Ebanks      Shannon Bond
# 7659        Dusty Dukatz              Lisa Huston  Michael Saquella
# 7660        Nkanya Nkwai             Lynno Lovert      Onyama Laura
# 7661        Pereko Mosia             Pereko Mosia  Siyabonga Mabaso
#
#              country      budget        gross                    company  \
# 0     United Kingdom  19000000.0   46998772.0               Warner Bros.
# 1      United States   4500000.0   58853106.0          Columbia Pictures
# 2      United States  18000000.0  538375067.0                  Lucasfilm
# 3      United States   3500000.0   83453539.0         Paramount Pictures
# 4      United States   6000000.0   39846344.0             Orion Pictures
# ...              ...         ...          ...                        ...
# 7657   United States  20500000.0   20205757.0        Abominable Pictures
# 7658   United States      7000.0   20205757.0            Unknown Company
# 7659   United States  20500000.0   20205757.0  Cactus Blue Entertainment
# 7660   United States     58750.0   20205757.0           Embi Productions
# 7661    South Africa  20500000.0   20205757.0                PK 65 Films
#
#       runtime
# 0       146.0
# 1       104.0
# 2       124.0
# 3        88.0
# 4        98.0
# ...       ...
# 7657     90.0
# 7658     90.0
# 7659     90.0
# 7660    104.0
# 7661    102.0
#
# [7662 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7662 non-null   object
#  1   rating    7662 non-null   object
#  2   genre     7662 non-null   object
#  3   year      7662 non-null   int64
#  4   released  7662 non-null   object
#  5   score     7662 non-null   float64
#  6   votes     7662 non-null   float64
#  7   director  7662 non-null   object
#  8   writer    7662 non-null   object
#  9   star      7662 non-null   object
#  10  country   7662 non-null   object
#  11  budget    7662 non-null   float64
#  12  gross     7662 non-null   float64
#  13  company   7662 non-null   object
#  14  runtime   7662 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.0+ KB

# %%
df['profit_ratio'] = df['gross'] / df['budget'].replace(0, np.nan)
def categorize_performance(r):
    if pd.isna(r):
        return "Unknown Performance" #budget == 0 case 
    if r < 1: return "Flop"
    elif r < 1.5: return "Average"
    elif r < 3: return "Hit"
    elif r < 5: return "Super Hit"
    elif r < 8: return "Blockbuster"
    else: return "All-Time Blockbuster"

df['performance_class'] = df['profit_ratio'].apply(categorize_performance)
df = df[df['performance_class'] != "Unknown Performance"]
df['performance_class'].count()
# Out:
# np.int64(7662)

# %%
def score_category(x):
    if x >= 8:
        return "Excellent"
    elif x >= 7:
        return "Very Good"
    elif x >= 6:
        return "Good"
    elif x >= 5:
        return "Average"
    elif x > 0:
        return "Poor"
    else:
        return "MissingScore"     # missing or 0 score
df["score_cat"] = df["score"].apply(score_category)


df["score_cat"].head()
# Out:
# 0    Excellent
# 1      Average
# 2    Excellent
# 3    Very Good
# 4    Very Good
# Name: score_cat, dtype: object

# %%
def classify_budget(b):  #us standards
    if b == 0: return "unknown Budget"
    elif b < 5_000_000: return "Low Budget"
    elif b < 50_000_000: return "Mid Budget"
    else: return "High Budget"

df["budget_cat"] = df["budget"].apply(classify_budget)

df["budget_cat"]
# Out:
# 0       Mid Budget
# 1       Low Budget
# 2       Mid Budget
# 3       Low Budget
# 4       Mid Budget
#            ...
# 7657    Mid Budget
# 7658    Low Budget
# 7659    Mid Budget
# 7660    Low Budget
# 7661    Mid Budget
# Name: budget_cat, Length: 7662, dtype: object

# %%
perf_order = ["All-Time Blockbuster", "Blockbuster", "Super Hit", "Hit", "Average", "Flop", "Unknown"]

dir_counts = df.groupby(['director', 'performance_class']).size().reset_index(name='count')
dir_pivot = dir_counts.pivot(index='director', columns='performance_class', values='count').fillna(0)

actor_counts = df.groupby(['star', 'performance_class']).size().reset_index(name='count')
actor_pivot = actor_counts.pivot(index='star', columns='performance_class', values='count').fillna(0)

for c in perf_order:
    if c not in dir_pivot.columns:
        dir_pivot[c] = 0
    if c not in actor_pivot.columns:
        actor_pivot[c] = 0

weights = {
    "All-Time Blockbuster": 15,
    "Blockbuster": 5,
    "Super Hit": 3,
    "Hit": 2,
    "Average": 1,
    "Flop": 0,
    "Unknown": 0
}

def compute_weighted_score(row):
    return sum(row[k] * w for k, w in weights.items())


dir_pivot['director_success_score'] = dir_pivot.apply(compute_weighted_score, axis=1)
actor_pivot['actor_success_score'] = actor_pivot.apply(compute_weighted_score, axis=1)

# # map back
df['director_success_score'] = df['director'].map(dir_pivot['director_success_score']).fillna(0)
df['actor_success_score'] = df['star'].map(actor_pivot['actor_success_score']).fillna(0)

actor_pivot.sort_values(by='actor_success_score',ascending=False).head(10)
# Out:
# performance_class      All-Time Blockbuster  Average  Blockbuster  Flop   Hit  \
# star
# Tom Hanks                               5.0      2.0         10.0   5.0  10.0
# Tom Cruise                              4.0      1.0          4.0   2.0  12.0
# Harrison Ford                           5.0      3.0          1.0   7.0   6.0
# Mel Gibson                              3.0      3.0          6.0   6.0   8.0
# Arnold Schwarzenegger                   3.0      4.0          3.0   4.0  10.0
# Robin Williams                          4.0      2.0          1.0  11.0   7.0
# Kevin Costner                           3.0      5.0          2.0   8.0   7.0
# Sylvester Stallone                      2.0      3.0          3.0   9.0   9.0
# Jim Carrey                              2.0      0.0          4.0   2.0   8.0
# Daniel Radcliffe                        4.0      0.0          4.0   4.0   0.0
#
# performance_class      Super Hit  Unknown  actor_success_score
# star
# Tom Hanks                    9.0        0                174.0
# Tom Cruise                  11.0        0                138.0
# Harrison Ford                4.0        0                107.0
# Mel Gibson                   3.0        0                103.0
# Arnold Schwarzenegger        3.0        0                 93.0
# Robin Williams               2.0        0                 87.0
# Kevin Costner                4.0        0                 86.0
# Sylvester Stallone           6.0        0                 84.0
# Jim Carrey                   6.0        0                 84.0
# Daniel Radcliffe             1.0        0                 83.0

# %%
def categorize_director(score):
    if score >= 30:
        return "Legendary-Director"
    elif score >= 15:
        return "High-Performer-Director"
    elif score >= 5:
        return "Medium-Director"
    else:
        return "Low-Director"

df['director_category'] = df['director_success_score'].apply(categorize_director)

# %%
def categorize_actor(score):
    if score >= 40:
        return "Legendary-Actor"
    elif score >= 20:
        return "High-Performer-Actor"
    elif score >= 8:
        return "Mid-Actor"
    else:
        return "Low-Actor"
df['actor_category'] = df['actor_success_score'].apply(categorize_actor)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    7662 non-null   object
#  1   rating                  7662 non-null   object
#  2   genre                   7662 non-null   object
#  3   year                    7662 non-null   int64
#  4   released                7662 non-null   object
#  5   score                   7662 non-null   float64
#  6   votes                   7662 non-null   float64
#  7   director                7662 non-null   object
#  8   writer                  7662 non-null   object
#  9   star                    7662 non-null   object
#  10  country                 7662 non-null   object
#  11  budget                  7662 non-null   float64
#  12  gross                   7662 non-null   float64
#  13  company                 7662 non-null   object
#  14  runtime                 7662 non-null   float64
#  15  profit_ratio            7662 non-null   float64
#  16  performance_class       7662 non-null   object
#  17  score_cat               7662 non-null   object
#  18  budget_cat              7662 non-null   object
#  19  director_success_score  7662 non-null   float64
#  20  actor_success_score     7662 non-null   float64
#  21  director_category       7662 non-null   object
#  22  actor_category          7662 non-null   object
# dtypes: float64(8), int64(1), object(14)
# memory usage: 1.3+ MB

# %%
df.to_csv("processed-movie.csv", index=False)
df
# Out:
#                                                 name          rating  \
# 0                                        The Shining               R
# 1                                    The Blue Lagoon               R
# 2     Star Wars: Episode V - The Empire Strikes Back              PG
# 3                                          Airplane!              PG
# 4                                         Caddyshack               R
# ...                                              ...             ...
# 7657                                Aloha Surf Hotel  Unknown Rating
# 7658                                    More to Life  Unknown Rating
# 7659                                     Dream Round  Unknown Rating
# 7660                                   Saving Mbango  Unknown Rating
# 7661                                       Tee em el  Unknown Rating
#
#           genre  year                          released  score      votes  \
# 0         Drama  1980     June 13, 1980 (United States)    8.4   927000.0
# 1     Adventure  1980      July 2, 1980 (United States)    5.8    65000.0
# 2        Action  1980     June 20, 1980 (United States)    8.7  1200000.0
# 3        Comedy  1980      July 2, 1980 (United States)    7.7   221000.0
# 4        Comedy  1980     July 25, 1980 (United States)    7.3   108000.0
# ...         ...   ...                               ...    ...        ...
# 7657     Comedy  2020  November 5, 2020 (United States)    7.1       14.0
# 7658      Drama  2020  October 23, 2020 (United States)    3.1       18.0
# 7659     Comedy  2020  February 7, 2020 (United States)    4.7       36.0
# 7660      Drama  2020         April 27, 2020 (Cameroon)    5.7       29.0
# 7661     Horror  2020   August 19, 2020 (United States)    5.7        7.0
#
#                 director                   writer              star  ...  \
# 0        Stanley Kubrick             Stephen King    Jack Nicholson  ...
# 1         Randal Kleiser  Henry De Vere Stacpoole    Brooke Shields  ...
# 2         Irvin Kershner           Leigh Brackett       Mark Hamill  ...
# 3           Jim Abrahams             Jim Abrahams       Robert Hays  ...
# 4           Harold Ramis       Brian Doyle-Murray       Chevy Chase  ...
# ...                  ...                      ...               ...  ...
# 7657  Stefan C. Schaefer       Stefan C. Schaefer       Augie Tulba  ...
# 7658       Joseph Ebanks            Joseph Ebanks      Shannon Bond  ...
# 7659        Dusty Dukatz              Lisa Huston  Michael Saquella  ...
# 7660        Nkanya Nkwai             Lynno Lovert      Onyama Laura  ...
# 7661        Pereko Mosia             Pereko Mosia  Siyabonga Mabaso  ...
#
#                         company  runtime  profit_ratio     performance_class  \
# 0                  Warner Bros.    146.0      2.473620                   Hit
# 1             Columbia Pictures    104.0     13.078468  All-Time Blockbuster
# 2                     Lucasfilm    124.0     29.909726  All-Time Blockbuster
# 3            Paramount Pictures     88.0     23.843868  All-Time Blockbuster
# 4                Orion Pictures     98.0      6.641057           Blockbuster
# ...                         ...      ...           ...                   ...
# 7657        Abominable Pictures     90.0      0.985647                  Flop
# 7658            Unknown Company     90.0   2886.536714  All-Time Blockbuster
# 7659  Cactus Blue Entertainment     90.0      0.985647                  Flop
# 7660           Embi Productions    104.0    343.927779  All-Time Blockbuster
# 7661                PK 65 Films    102.0      0.985647                  Flop
#
#       score_cat  budget_cat director_success_score actor_success_score  \
# 0     Excellent  Mid Budget                    6.0                25.0
# 1       Average  Low Budget                   20.0                17.0
# 2     Excellent  Mid Budget                   19.0                30.0
# 3     Very Good  Low Budget                   36.0                22.0
# 4     Very Good  Mid Budget                   16.0                34.0
# ...         ...         ...                    ...                 ...
# 7657  Very Good  Mid Budget                    0.0                 0.0
# 7658       Poor  Low Budget                   15.0                15.0
# 7659       Poor  Mid Budget                    0.0                 0.0
# 7660    Average  Low Budget                   15.0                15.0
# 7661    Average  Mid Budget                    0.0                 0.0
#
#             director_category        actor_category
# 0             Medium-Director  High-Performer-Actor
# 1     High-Performer-Director             Mid-Actor
# 2     High-Performer-Director  High-Performer-Actor
# 3          Legendary-Director  High-Performer-Actor
# 4     High-Performer-Director  High-Performer-Actor
# ...                       ...                   ...
# 7657             Low-Director             Low-Actor
# 7658  High-Performer-Director             Mid-Actor
# 7659             Low-Director             Low-Actor
# 7660  High-Performer-Director             Mid-Actor
# 7661             Low-Director             Low-Actor
#
# [7662 rows x 23 columns]
